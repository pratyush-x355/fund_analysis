# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import os

import libraries.fund_analytics as fund_analytics
importlib.reload(fund_analytics)

from libraries.fund_analytics import PortfolioAnalytics

# %% [markdown]
# ##### WS fund data analysis

# %%
file_path = os.getcwd() + '/data/ws_ls_fund.xlsx'
fund_data = pd.read_excel(file_path)

import libraries.help as help
importlib.reload(help)
from libraries.help import calculate_monthly_performance_fees
data = calculate_monthly_performance_fees(fund_data, annual_performance_fee_rate=0.2,annual_hurdle_rate=0.06)
data = data.drop(['annual_performance_fee', 'annual_return', 'excess_return_annual'], axis = 1)
# Out:
# Annual Performance Fee Calculation:
# ============================================================
# Year 2020:
#   Annual Gross Return:       4.74%
#   Hurdle Rate:               6.00%
#   Below Hurdle - No Performance Fee
# ----------------------------------------
# Year 2021:
#   Annual Gross Return:      17.01%
#   Hurdle Rate:               6.00%
#   Excess Return:            11.01%
#   Annual Performance Fee:  2.2020%
#   Monthly Performance Fee: 0.1835%
#   Months in year:               12
# ----------------------------------------
# Year 2022:
#   Annual Gross Return:       7.33%
#   Hurdle Rate:               6.00%
#   Excess Return:             1.33%
#   Annual Performance Fee:  0.2660%
#   Monthly Performance Fee: 0.0222%
#   Months in year:               12
# ----------------------------------------
# Year 2023:
#   Annual Gross Return:      15.00%
#   Hurdle Rate:               6.00%
#   Excess Return:             9.00%
#   Annual Performance Fee:  1.8000%
#   Monthly Performance Fee: 0.1500%
#   Months in year:               12
# ----------------------------------------
# Year 2024:
#   Annual Gross Return:      14.45%
#   Hurdle Rate:               6.00%
#   Excess Return:             8.45%
#   Annual Performance Fee:  1.6900%
#   Monthly Performance Fee: 0.1408%
#   Months in year:               12
# ----------------------------------------
# Year 2025:
#   Annual Gross Return:       7.17%
#   Hurdle Rate:               6.00%
#   Excess Return:             1.17%
#   Annual Performance Fee:  0.2348%
#   Monthly Performance Fee: 0.0261%
#   Months in year:                9
# ----------------------------------------
#
# SUMMARY:
# Total Years:                    6
# Years with Performance Fees:    5
# Years without Performance Fees: 1
# Average Annual Performance Fee: 1.2386%

# %%
# Initialize analytics
portfolio = PortfolioAnalytics(data)

# Generate comprehensive report
results = portfolio.generate_report()

# Create plots
fig = portfolio.create_plots()
plt.show()

# Export to Excel
portfolio.export_results('portfolio_analysis.xlsx')
# Out:
# ================================================================================
# PORTFOLIO PERFORMANCE ANALYTICS REPORT
# ================================================================================
#
# 📊 BASIC PERFORMANCE METRICS
# --------------------------------------------------
# Gross Annual Return:      13.72%
# Net Annual Return:        9.76%
# Benchmark Return:         6.02%
# Cash Return:              6.00%
#
# Gross Volatility:         3.46%
# Net Volatility:           3.41%
# Benchmark Volatility:     1.15%
#
# Gross Sharpe Ratio:       2.047
# Net Sharpe Ratio:         1.030
#
# ⚠️  RISK METRICS
# --------------------------------------------------
# Max Drawdown (Gross):     -4.62%
# Max Drawdown (Net):       -5.29%
# Max DD Duration (Gross):  6 months
# Max DD Duration (Net):    7 months
#
# VaR (5%, Gross):          -0.19% monthly
# VaR (5%, Net):            -0.41% monthly
# Expected Shortfall (Gross): -1.41% monthly
# Expected Shortfall (Net):   -1.63% monthly
#
# 📈 BETA AND TRACKING METRICS
# --------------------------------------------------
# Beta (Gross):             0.013
# Beta (Net):               0.012
# Tracking Error (Gross):   3.54%
# Tracking Error (Net):     3.50%
# Information Ratio (Gross): 1.995
# Information Ratio (Net):   0.998
#
# 💰 EXCESS RETURNS
# --------------------------------------------------
# Excess Return vs Cash (Gross):      7.72%
# Excess Return vs Cash (Net):        3.76%
# Excess Return vs Benchmark (Gross): 7.70%
# Excess Return vs Benchmark (Net):   3.74%
#
# 🔄 REGIME ANALYSIS
# --------------------------------------------------
#                 gross_return  net_return  benchmark_return  excess_return_gross  excess_return_net  volatility_gross  volatility_net  sharpe_gross  sharpe_net  periods
# Risky Bullish         0.1725      0.1394            0.0382               0.1342             0.1012            0.0243          0.0229        4.7026      3.5333      7.0
# Stable Bullish        0.1502      0.1114            0.0667               0.0835             0.0447            0.0237          0.0240        3.8688      2.2086     34.0
# Neutral               0.0786      0.0470            0.0520               0.0266            -0.0050            0.0477          0.0469        0.4237     -0.2438     20.0
# Results exported to portfolio_analysis.xlsx
# 'portfolio_analysis.xlsx'

# %% [markdown]
# ##### DC Fund data analysis

# %%
file_path = os.getcwd() + '/data/dc_fi_fund.xlsx'
fund_data = pd.read_excel(file_path)

import libraries.help as help
importlib.reload(help)
from libraries.help import calculate_monthly_performance_fees
data = calculate_monthly_performance_fees(fund_data, annual_performance_fee_rate=0.2,annual_hurdle_rate=0.10)

data = data.drop(['annual_performance_fee', 'annual_return', 'excess_return_annual'], axis = 1)
# Out:
# Annual Performance Fee Calculation:
# ============================================================
# Year 2021:
#   Annual Gross Return:       7.11%
#   Hurdle Rate:              10.00%
#   Below Hurdle - No Performance Fee
# ----------------------------------------
# Year 2022:
#   Annual Gross Return:       8.41%
#   Hurdle Rate:              10.00%
#   Below Hurdle - No Performance Fee
# ----------------------------------------
# Year 2023:
#   Annual Gross Return:      15.26%
#   Hurdle Rate:              10.00%
#   Excess Return:             5.26%
#   Annual Performance Fee:  1.0520%
#   Monthly Performance Fee: 0.0877%
#   Months in year:               12
# ----------------------------------------
# Year 2024:
#   Annual Gross Return:      15.32%
#   Hurdle Rate:              10.00%
#   Excess Return:             5.32%
#   Annual Performance Fee:  1.0640%
#   Monthly Performance Fee: 0.0887%
#   Months in year:               12
# ----------------------------------------
# Year 2025:
#   Annual Gross Return:       4.24%
#   Hurdle Rate:              10.00%
#   Below Hurdle - No Performance Fee
# ----------------------------------------
#
# SUMMARY:
# Total Years:                    5
# Years with Performance Fees:    2
# Years without Performance Fees: 3
# Average Annual Performance Fee: 1.0580%

# %%
# Initialize analytics
portfolio = PortfolioAnalytics(data)

# Generate comprehensive report
results = portfolio.generate_report()

# Create plots
fig = portfolio.create_plots()
plt.show()

# Export to Excel
portfolio.export_results('portfolio_analysis.xlsx')
# Out:
# ================================================================================
# PORTFOLIO PERFORMANCE ANALYTICS REPORT
# ================================================================================
#
# 📊 BASIC PERFORMANCE METRICS
# --------------------------------------------------
# Gross Annual Return:      11.55%
# Net Annual Return:        9.43%
# Benchmark Return:         6.27%
# Cash Return:              6.00%
#
# Gross Volatility:         2.42%
# Net Volatility:           2.35%
# Benchmark Volatility:     0.64%
#
# Gross Sharpe Ratio:       2.125
# Net Sharpe Ratio:         1.361
#
# ⚠️  RISK METRICS
# --------------------------------------------------
# Max Drawdown (Gross):     -0.38%
# Max Drawdown (Net):       -0.62%
# Max DD Duration (Gross):  2 months
# Max DD Duration (Net):    3 months
#
# VaR (5%, Gross):          -0.18% monthly
# VaR (5%, Net):            -0.30% monthly
# Expected Shortfall (Gross): -0.30% monthly
# Expected Shortfall (Net):   -0.45% monthly
#
# 📈 BETA AND TRACKING METRICS
# --------------------------------------------------
# Beta (Gross):             0.056
# Beta (Net):               0.055
# Tracking Error (Gross):   2.32%
# Tracking Error (Net):     2.28%
# Information Ratio (Gross): 2.104
# Information Ratio (Net):   1.295
#
# 💰 EXCESS RETURNS
# --------------------------------------------------
# Excess Return vs Cash (Gross):      5.55%
# Excess Return vs Cash (Net):        3.43%
# Excess Return vs Benchmark (Gross): 5.28%
# Excess Return vs Benchmark (Net):   3.16%
#
# 🔄 REGIME ANALYSIS
# --------------------------------------------------
#                 gross_return  net_return  benchmark_return  excess_return_gross  excess_return_net  volatility_gross  volatility_net  sharpe_gross  sharpe_net  periods
# Risky Bullish         0.0652      0.0504            0.0635               0.0016            -0.0131               NaN             NaN           NaN         NaN      1.0
# Stable Bullish        0.1340      0.1140            0.0624               0.0716             0.0516            0.0250          0.0240        3.0232      2.3117     34.0
# Neutral               0.0710      0.0525            0.0584               0.0126            -0.0058            0.0187          0.0189        0.6712     -0.3112     20.0
# Results exported to portfolio_analysis.xlsx
# 'portfolio_analysis.xlsx'

# %% [markdown]
# ##### Mutual Fund analysis

# %%
file_path = os.getcwd() + '/data/mf_data.xlsx'

fund_data = pd.read_excel(file_path)

fund_data.set_index('date', inplace=True)

# %%
# Initialize analytics
portfolio = PortfolioAnalytics(fund_data)

# Generate comprehensive report
results = portfolio.generate_report()

# Create plots
fig = portfolio.create_plots()
plt.show()

# Export to Excel
portfolio.export_results('portfolio_analysis.xlsx')
# Out:
# Warning: Missing values detected in numeric columns
# ================================================================================
# PORTFOLIO PERFORMANCE ANALYTICS REPORT
# ================================================================================
#
# 📊 BASIC PERFORMANCE METRICS
# --------------------------------------------------
# Gross Annual Return:      26.70%
# Net Annual Return:        27.80%
# Benchmark Return:         16.83%
# Cash Return:              6.00%
#
# Gross Volatility:         22.50%
# Net Volatility:           22.97%
# Benchmark Volatility:     18.12%
#
# Gross Sharpe Ratio:       0.802
# Net Sharpe Ratio:         0.824
#
# ⚠️  RISK METRICS
# --------------------------------------------------
# Max Drawdown (Gross):     -39.93%
# Max Drawdown (Net):       -39.93%
# Max DD Duration (Gross):  12 months
# Max DD Duration (Net):    12 months
#
# VaR (5%, Gross):          -5.96% monthly
# VaR (5%, Net):            nan% monthly
# Expected Shortfall (Gross): -17.58% monthly
# Expected Shortfall (Net):   nan% monthly
#
# 📈 BETA AND TRACKING METRICS
# --------------------------------------------------
# Beta (Gross):             0.923
# Beta (Net):               nan
# Tracking Error (Gross):   12.77%
# Tracking Error (Net):     12.39%
# Information Ratio (Gross): 0.645
# Information Ratio (Net):   0.565
#
# 💰 EXCESS RETURNS
# --------------------------------------------------
# Excess Return vs Cash (Gross):      20.70%
# Excess Return vs Cash (Net):        21.80%
# Excess Return vs Benchmark (Gross): 9.87%
# Excess Return vs Benchmark (Net):   10.97%
#
# 🔄 REGIME ANALYSIS
# --------------------------------------------------
#                 gross_return  net_return  benchmark_return  excess_return_gross  excess_return_net  volatility_gross  volatility_net  sharpe_gross  sharpe_net  periods
# Stable Bullish        0.4153      0.3865            0.2613               0.1540             0.1185            0.1088          0.1075        3.2793      3.0517     40.0
# Neutral               0.0155      0.1216           -0.0542               0.0697             0.1207            0.2105          0.1797       -0.2040      0.3515     26.0
# Volatile             -0.6202     -0.6202           -0.2424              -0.3778            -0.3778            0.6404          0.6404       -1.0596     -1.0596      5.0
# Risky Bullish         0.6206      0.6206            0.5672               0.0534             0.0534            0.1323          0.1323        4.2487      4.2487      8.0
# Results exported to portfolio_analysis.xlsx
# 'portfolio_analysis.xlsx'

# %%
file_path = os.getcwd() + '/data/gold.xlsx'

fund_data = pd.read_excel(file_path)

fund_data.set_index('date', inplace=True)

# %%
# Initialize analytics
portfolio = PortfolioAnalytics(fund_data)

# Generate comprehensive report
results = portfolio.generate_report()

# Create plots
fig = portfolio.create_plots()
plt.show()

# Export to Excel
portfolio.export_results('portfolio_analysis.xlsx')
# Out:
# ================================================================================
# PORTFOLIO PERFORMANCE ANALYTICS REPORT
# ================================================================================
#
# 📊 BASIC PERFORMANCE METRICS
# --------------------------------------------------
# Gross Annual Return:      17.72%
# Net Annual Return:        15.44%
# Benchmark Return:         6.00%
# Cash Return:              6.00%
#
# Gross Volatility:         12.72%
# Net Volatility:           12.72%
# Benchmark Volatility:     0.00%
#
# Gross Sharpe Ratio:       0.833
# Net Sharpe Ratio:         0.677
#
# ⚠️  RISK METRICS
# --------------------------------------------------
# Max Drawdown (Gross):     -18.64%
# Max Drawdown (Net):       -19.74%
# Max DD Duration (Gross):  29 months
# Max DD Duration (Net):    31 months
#
# VaR (5%, Gross):          -4.10% monthly
# VaR (5%, Net):            -4.26% monthly
# Expected Shortfall (Gross): -4.98% monthly
# Expected Shortfall (Net):   -5.15% monthly
#
# 📈 BETA AND TRACKING METRICS
# --------------------------------------------------
# Beta (Gross):             -0.154
# Beta (Net):               -0.154
# Tracking Error (Gross):   12.72%
# Tracking Error (Net):     12.72%
# Information Ratio (Gross): 0.833
# Information Ratio (Net):   0.677
#
# 💰 EXCESS RETURNS
# --------------------------------------------------
# Excess Return vs Cash (Gross):      11.72%
# Excess Return vs Cash (Net):        9.44%
# Excess Return vs Benchmark (Gross): 11.72%
# Excess Return vs Benchmark (Net):   9.44%
#
# 🔄 REGIME ANALYSIS
# --------------------------------------------------
#                 gross_return  net_return  benchmark_return  excess_return_gross  excess_return_net  volatility_gross  volatility_net  sharpe_gross  sharpe_net  periods
# Stable Bullish        0.1195      0.0997            0.0584               0.0611             0.0413            0.1156          0.1156        0.5283      0.3568     40.0
# Neutral               0.2600      0.2402            0.0584               0.2016             0.1818            0.1202          0.1202        1.6777      1.5127     26.0
# Volatile              0.4178      0.3980            0.0584               0.3594             0.3396            0.1300          0.1300        2.7656      2.6131      5.0
# Risky Bullish        -0.0812     -0.1010            0.0584              -0.1396            -0.1594            0.1765          0.1765       -0.7911     -0.9034      8.0
# Results exported to portfolio_analysis.xlsx
# 'portfolio_analysis.xlsx'

# %% [markdown]
# ##### Deriv Strategy - simulated return

# %%
def simulate_portfolio(df, target_return_ann=0.14, beta=0.2):
    """
    df : pd.DataFrame with columns ["Market", "Cash"] containing monthly returns (as decimals, e.g. 0.01 = 1%)
    target_return_ann : target annualized return (e.g. 0.14 for 14%)
    beta : desired beta to market
    """
    n_months = len(df)
    periods_per_year = 12
    
    # Convert annual to monthly return
    target_return_monthly = (1 + target_return_ann)**(1/periods_per_year) - 1
    
    # Expected monthly values from series
    market_mean = df["market_return"].mean()
    cash_mean = df["cash_return"].mean()
    
    # Solve for alpha
    alpha = target_return_monthly - (beta * market_mean + (1 - beta) * cash_mean)
    
    # Construct portfolio returns series
    df["gross_return"] = alpha + beta * df["market_return"] + (1 - beta) * df["cash_return"]
    
    return df, alpha

# %%
file_path = os.getcwd() + '/data/prop_strat.xlsx'
df = pd.read_excel(file_path)
fund_data, alpha = simulate_portfolio(df, target_return_ann=0.14, beta=0.2) # Create the simulated fund data with 20% beta
fund_data.set_index('date', inplace=True)

# %%
# Initialize analytics
portfolio = PortfolioAnalytics(fund_data)

# Generate comprehensive report
results = portfolio.generate_report()

# Create plots
fig = portfolio.create_plots()
plt.show()

# Export to Excel
portfolio.export_results('portfolio_analysis.xlsx')
# Out:
# ================================================================================
# PORTFOLIO PERFORMANCE ANALYTICS REPORT
# ================================================================================
#
# 📊 BASIC PERFORMANCE METRICS
# --------------------------------------------------
# Gross Annual Return:      14.00%
# Net Annual Return:        8.61%
# Benchmark Return:         6.00%
# Cash Return:              6.00%
#
# Gross Volatility:         4.41%
# Net Volatility:           4.41%
# Benchmark Volatility:     0.00%
#
# Gross Sharpe Ratio:       1.663
# Net Sharpe Ratio:         0.554
#
# ⚠️  RISK METRICS
# --------------------------------------------------
# Max Drawdown (Gross):     -6.28%
# Max Drawdown (Net):       -7.07%
# Max DD Duration (Gross):  4 months
# Max DD Duration (Net):    6 months
#
# VaR (5%, Gross):          -0.56% monthly
# VaR (5%, Net):            -0.96% monthly
# Expected Shortfall (Gross): -2.28% monthly
# Expected Shortfall (Net):   -2.69% monthly
#
# 📈 BETA AND TRACKING METRICS
# --------------------------------------------------
# Beta (Gross):             0.203
# Beta (Net):               0.203
# Tracking Error (Gross):   4.41%
# Tracking Error (Net):     4.41%
# Information Ratio (Gross): 1.663
# Information Ratio (Net):   0.554
#
# 💰 EXCESS RETURNS
# --------------------------------------------------
# Excess Return vs Cash (Gross):      8.00%
# Excess Return vs Cash (Net):        2.61%
# Excess Return vs Benchmark (Gross): 8.00%
# Excess Return vs Benchmark (Net):   2.61%
#
# 🔄 REGIME ANALYSIS
# --------------------------------------------------
#                 gross_return  net_return  benchmark_return  excess_return_gross  excess_return_net  volatility_gross  volatility_net  sharpe_gross  sharpe_net  periods
# Stable Bullish        0.1573      0.1084            0.0584               0.0989             0.0500            0.0231          0.0231        4.2711      2.1589     40.0
# Neutral               0.0853      0.0365            0.0584               0.0269            -0.0220            0.0379          0.0379        0.7099     -0.5786     26.0
# Volatile              0.0132     -0.0357            0.0584              -0.0452            -0.0941            0.1296          0.1296       -0.3490     -0.7262      5.0
# Risky Bullish         0.2290      0.1801            0.0584               0.1706             0.1217            0.0350          0.0350        4.8788      3.4807      8.0
# Results exported to portfolio_analysis.xlsx
# 'portfolio_analysis.xlsx'
